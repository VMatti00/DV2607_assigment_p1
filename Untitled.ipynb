# %%
import pandas as pd

# %%
import random

# %%
PATH =  "data/train_data.csv"

# %%
train_data = pd.read_csv(PATH)

# %%
train_data
# Out:
#            LIMIT_BAL  AGE       PAY_0       PAY_2       PAY_3       PAY_4  \
# 0       120000.00000   49     0.00000    -1.00000    -1.00000    -1.00000
# 1        30000.00000   38     2.00000     0.00000     0.00000     0.00000
# 2        90000.00000   39     0.00000     0.00000     0.00000     0.00000
# 3       130000.00000   26     0.00000     0.00000     2.00000     2.00000
# 4        50000.00000   26     2.00000     0.00000     0.00000     0.00000
# ...              ...  ...         ...         ...         ...         ...
# 160899  415895.50004   25 -4042.49996 -4043.49996 -4043.49996 -4043.49996
# 160900  415895.50004   25 -4042.49996 -4043.49996 -4043.49996 -4043.49996
# 160901  415895.50004   25 -4042.49996 -4043.49996 -4043.49996 -4043.49996
# 160902  415899.50004   25 -4042.49996 -4043.49996 -4043.49996 -4043.49996
# 160903  415899.50004   25 -4042.49996 -4043.49996 -4043.49996 -4043.49996
#
#              PAY_5       PAY_6     BILL_AMT1     BILL_AMT2  ...  BILL_AMT4  \
# ...

# %%
train_data.iloc[:,-1].head()
# Out:
# 0    1.0
# 1    0.0
# 2    1.0
# 3    0.0
# 4    1.0
# Name: default payment next month, dtype: float64

# %%
for i in range(160904):
    temp = train_data.iloc[i,-1]
    #print(train_data.iloc[i,-1],"\n")
    train_data.iloc[i,-1]= random.randint(0,1)
    #print(train_data.iloc[i,-1],"\n\n")
    train_data.iloc[i,]
# Out:
# Cahnge at index 2
# Cahnge at index 3
# Cahnge at index 6
# Cahnge at index 7
# Cahnge at index 8
# Cahnge at index 9
# Cahnge at index 14
# Cahnge at index 23
# Cahnge at index 25
# Cahnge at index 27
# Cahnge at index 28
# Cahnge at index 29
# Cahnge at index 31
# Cahnge at index 32
# Cahnge at index 33
# Cahnge at index 34
# Cahnge at index 35
# Cahnge at index 40
# Cahnge at index 43
# Cahnge at index 44
# Cahnge at index 45
# Cahnge at index 49
# Cahnge at index 51
# Cahnge at index 52
# Cahnge at index 55
# Cahnge at index 57
# Cahnge at index 58
# Cahnge at index 67
# Cahnge at index 68
# Cahnge at index 72
# Cahnge at index 82
# Cahnge at index 86
# Cahnge at index 88
# Cahnge at index 89
# Cahnge at index 90
# Cahnge at index 93
# Cahnge at index 94
# Cahnge at index 95
# Cahnge at index 96
# Cahnge at index 98
# Cahnge at index 105
# Cahnge at index 107
# Cahnge at index 114
# Cahnge at index 116
# Cahnge at index 120
# Cahnge at index 122
# Cahnge at index 123
# ...

# %%
random.randint(0,1)
# Out:
# 0

# %%
160904

# %%
train_data.iloc[0,'default payment next mont']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:940, in _LocationIndexer._validate_tuple_indexer(self, key)
#     939 try:
# --> 940     self._validate_key(k, i)
#     941 except ValueError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1576, in _iLocIndexer._validate_key(self, key, axis)
#    1575 else:
# -> 1576     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 train_data.iloc[0,'default payment next mont']
#
# ...

# %%
m=0
for i in train_data:
    print(i, " is at index ", m)
    m +=1
# Out:
# LIMIT_BAL  is at index  0
# AGE  is at index  1
# PAY_0  is at index  2
# PAY_2  is at index  3
# PAY_3  is at index  4
# PAY_4  is at index  5
# PAY_5  is at index  6
# PAY_6  is at index  7
# BILL_AMT1  is at index  8
# BILL_AMT2  is at index  9
# BILL_AMT3  is at index  10
# BILL_AMT4  is at index  11
# BILL_AMT5  is at index  12
# BILL_AMT6  is at index  13
# PAY_AMT1  is at index  14
# PAY_AMT2  is at index  15
# PAY_AMT3  is at index  16
# PAY_AMT4  is at index  17
# PAY_AMT5  is at index  18
# PAY_AMT6  is at index  19
# default payment next month  is at index  20

# %%
train_data.iloc[20,0]
# Out:
# 30000.0
